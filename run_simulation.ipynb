# %%
import gov_inertia as gi

# %%
parameters = gi.initial_conditions

# %%
history = gi.run_simulation(parameters, 1500)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 1500/1500 [00:00<00:00, 16503.87it/s]

# %%
import pandas as pd
df = pd.DataFrame(history)
df
# Out:
#                  N     m   k           G  H_0             H  rho  theta    F  \
# 0     1.000000e+03  0.01  50    3.000000    1  7.114806e+01  1.5    3.5  0.1
# 1     1.015000e+03  0.01  50    3.000026    1  7.115020e+01  1.5    3.5  0.1
# 2     1.030225e+03  0.01  50    3.000029    1  7.115039e+01  1.5    3.5  0.1
# 3     1.045678e+03  0.01  50    3.000030    1  7.115051e+01  1.5    3.5  0.1
# 4     1.061364e+03  0.01  50    3.000052    1  7.115229e+01  1.5    3.5  0.1
# ...            ...   ...  ..         ...  ...           ...  ...    ...  ...
# 1496  4.711934e+12  0.01  50  253.453541    1  3.888083e+08  1.5    3.5  0.1
# 1497  4.782613e+12  0.01  50  254.206908    1  3.928683e+08  1.5    3.5  0.1
# 1498  4.854352e+12  0.01  50  254.658885    1  3.953185e+08  1.5    3.5  0.1
# 1499  4.927168e+12  0.01  50  255.383233    1  3.992681e+08  1.5    3.5  0.1
# 1500  5.001075e+12  0.01  50  255.465413    1  3.997179e+08  1.5    3.5  0.1
#
#       alpha  ...  lambda  psi    epsilon   zeta  eta  C_B  omega  \
# 0       0.5  ...   0.001  0.5  10.000000  0.001  0.7    3   0.95
# 1       0.5  ...   0.001  0.5   9.999942  0.100  0.7    3   0.95
# 2       0.5  ...   0.001  0.5   9.999934  0.100  0.7    3   0.95
# 3       0.5  ...   0.001  0.5   9.999926  0.100  0.7    3   0.95
# 4       0.5  ...   0.001  0.5   9.999916  0.100  0.7    3   0.95
# ...     ...  ...     ...  ...        ...    ...  ...  ...    ...
# 1496    0.5  ...   0.001  0.5   0.000010  0.100  0.7    3   0.95
# 1497    0.5  ...   0.001  0.5   0.000010  0.100  0.7    3   0.95
# 1498    0.5  ...   0.001  0.5   0.000010  0.100  0.7    3   0.95
# 1499    0.5  ...   0.001  0.5   0.000010  0.100  0.7    3   0.95
# 1500    0.5  ...   0.001  0.5   0.000010  0.100  0.7    3   0.95
#
#       stolen_funds       savings  growth_rate
# 0     0.000000e+00  0.000000e+00        0.015
# 1     4.366869e-03  2.037556e-02        0.015
# 2     4.941647e-03  2.168574e-02        0.015
# 3     5.364183e-03  2.279022e-02        0.015
# 4     9.357407e-03  4.615831e-02        0.015
# ...            ...           ...          ...
# 1496  7.918846e+10  3.682018e+11        0.015
# 1497  8.034654e+10  3.756121e+11        0.015
# 1498  8.156604e+10  3.816559e+11        0.015
# 1499  8.303020e+10  3.860248e+11        0.015
# 1500  8.430241e+10  3.932219e+11        0.015
#
# [1501 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['N', 'm', 'k', 'G', 'H_0', 'H', 'rho', 'theta', 'F', 'alpha', 'beta',
#        'gamma', 'delta', 'mu_0', 'sigma', 'tau', 'lambda', 'psi', 'epsilon',
#        'zeta', 'eta', 'C_B', 'omega', 'stolen_funds', 'savings',
#        'growth_rate'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

plot_cols = ['N','G','H','mu_0','epsilon', 'savings','stolen_funds','tau','delta','zeta']
for col in plot_cols:
    plt.scatter(df.index, df[col])
    plt.title(col)
    plt.show()

# %%
results = history
# Extract lists of values for plotting
G = [d['G'] for d in results]
N = [d['N'] for d in results]
H = [d['H'] for d in results]
savings = [d['savings'] for d in results]
epsilon = [d['epsilon'] for d in results]
# C_

plt.figure(figsize=(12, 8))

# Plot N vs G
plt.subplot(2, 2, 1)
plt.plot(G, N, marker='o')
plt.title('N vs G')
plt.xlabel('G')
plt.ylabel('N')

# Plot H vs G
plt.subplot(2, 2, 2)
plt.plot(G, H, 'orange', marker='o')
plt.title('H vs G')
plt.xlabel('G')
plt.ylabel('H')

# Plot savings vs G
plt.subplot(2, 2, 3)
plt.plot(G, savings, 'green', marker='o')
plt.title('Savings vs G')
plt.xlabel('G')
plt.ylabel('Savings')
# plt.yscale('log')

# Plot epsilon vs G
plt.subplot(2, 2, 4)
plt.plot(G, epsilon, 'red', marker='o')
plt.title('Epsilon vs G')
plt.xlabel('G')
plt.ylabel('Epsilon')
# plt.xscale('log')
# plt.yscale('log')
plt.tight_layout()
plt.show()
